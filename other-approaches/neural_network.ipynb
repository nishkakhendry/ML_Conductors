# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import numpy.linalg as LA
from copy import deepcopy
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# 2022-04-17 13:31:17.293098: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-17 13:31:17.293115: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
DATA_PATH = './nomad2018-predict-transparent-conductors'

def custom_converter(entry):
    return np.array([float(x) for x in entry[1:-1].split(',')])

train_all_data = pd.read_csv(
    f'{DATA_PATH}/train_extrainfo.csv',
    converters={
        'CoulombMatrix':custom_converter,
        'SineMatrix':custom_converter,
        'EwaldSumMatrix':custom_converter
    }
)
test_all_data = pd.read_csv(
    f'{DATA_PATH}/test_extrainfo.csv',
    converters={
        'CoulombMatrix':custom_converter,
        'SineMatrix':custom_converter,
        'EwaldSumMatrix':custom_converter
    }
)

# %%
train_all_data.columns
# Out:
# Index(['id', 'spacegroup', 'number_of_total_atoms', 'percent_atom_al',
#        'percent_atom_ga', 'percent_atom_in', 'lattice_vector_1_ang',
#        'lattice_vector_2_ang', 'lattice_vector_3_ang',
#        'lattice_angle_alpha_degree', 'lattice_angle_beta_degree',
#        'lattice_angle_gamma_degree', 'formation_energy_ev_natom',
#        'bandgap_energy_ev', 'CoulombMatrix', 'SineMatrix', 'EwaldSumMatrix'],
#       dtype='object')

# %%
def get_eigenspectrum(matrix):
    spectrum = LA.eigvalsh(matrix)
    spectrum = np.sort(spectrum)[::-1]
    return spectrum

def preprocess(data, train=True):
    data = deepcopy(data)
    spectrum_list = []
    for m in data['SineMatrix']:
        spectrum_list.append(
            get_eigenspectrum(
                np.reshape(m, (80, 80))
            )
        )
    spectrum_df = pd.DataFrame(spectrum_list).astype(float)
    if train:
        to_drop = ['id', 'formation_energy_ev_natom', 'bandgap_energy_ev',
                'CoulombMatrix', 'SineMatrix', 'EwaldSumMatrix']
    else:
        to_drop = ['id',
               'CoulombMatrix', 'SineMatrix', 'EwaldSumMatrix']
    dfcombined = pd.concat([data, spectrum_df], axis=1).drop(to_drop, axis=1)
    return dfcombined

# %%
target_cols = ['formation_energy_ev_natom','bandgap_energy_ev']
data = preprocess(train_all_data)

X_train, X_test, y_train, y_test = train_test_split(data, train_all_data[target_cols], test_size = 0.30, random_state=1)

# %%
X_train
# Out:
#       spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 60           206                   80.0           0.0938           0.6875
# 2079         206                   80.0           0.4062           0.2500
# 1395          33                   40.0           0.0000           0.6250
# 2227          33                   80.0           0.0000           0.3125
# 701          206                   80.0           0.7500           0.2500
# ...          ...                    ...              ...              ...
# 960          167                   30.0           0.0000           0.1667
# 905           33                   80.0           0.3438           0.0312
# 1096          12                   80.0           0.5000           0.1875
# 235          167                   30.0           0.4167           0.0833
# 1061          12                   80.0           0.0312           0.3125
#
#       percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 60             0.2188                9.5583                9.5583
# 2079           0.3438                9.5382                9.5379
# 1395           0.3750                5.3302                9.1151
# 2227           0.6875               11.0070                9.3773
# 701            0.0000                9.0894                9.0888
# ...               ...                   ...                   ...
# 960            0.8333                5.4918                5.4913
# 905            0.6250               10.7770                9.1878
# 1096           0.3125               24.3195                6.2018
# 235            0.5000                5.2158                5.2154
# 1061           0.6562               24.7160                6.5275
#
#       lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 60                  9.5580                     90.0045
# 2079                9.5380                     90.0024
# 1395                9.7342                     89.9979
# 2227                9.9993                     89.9990
# 701                 9.0890                     90.0034
# ...                    ...                         ...
# 960                14.5600                     89.9984
# 905                 9.8151                     90.0022
# 1096                6.0952                     89.9996
# 235                13.9784                     89.9940
# 1061                6.5440                     90.0003
#
#       lattice_angle_beta_degree  ...         70         71         72  \
# 60                      90.0040  ...  51.278905  51.192050  50.684798
# 2079                    90.0027  ...  48.124473  47.073484  46.151431
# 1395                    89.9997  ...   0.000000   0.000000   0.000000
# 2227                    89.9976  ...  53.141250  52.234727  52.214577
# 701                     90.0041  ...  38.356714  37.568985  36.881481
# ...                         ...  ...        ...        ...        ...
# 960                     89.9993  ...   0.000000   0.000000   0.000000
# 905                     89.9990  ...  51.358700  50.391844  49.539896
# 1096                   104.7008  ...  40.919317  40.599176  38.824526
# 235                     90.0058  ...   0.000000   0.000000   0.000000
# 1061                   105.4012  ...  48.229816  46.007868  43.207590
#
#              73         74         75         76         77         78  \
# 60    50.255256  49.243095  48.444891  48.437744  47.624117  41.435008
# 2079  44.098866  41.950107  40.599060  39.816876  38.936680  37.261905
# 1395   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2227  51.469821  51.383424  50.551757  47.950949  47.940750  47.005041
# 701   35.529089  34.133708  33.929112  31.491647  31.410154  30.403501
# ...         ...        ...        ...        ...        ...        ...
# 960    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 905   49.029609  48.132958  47.697284  46.699077  46.315230  46.134322
# 1096  36.662027  35.667331  32.352772  29.573998  25.913214  24.889890
# 235    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1061  43.093109  41.523991  34.572891  33.415265  30.085081  29.948745
#
#              79
# 60    39.785544
# 2079  34.584100
# 1395   0.000000
# 2227  45.728682
# 701   23.782710
# ...         ...
# 960    0.000000
# 905   42.784553
# 1096  23.723443
# 235    0.000000
# 1061  28.716507
#
# [1680 rows x 91 columns]

# %%
X_train.to_numpy().shape
# Out:
# (1680, 91)

# %%
model = models.Sequential([
    layers.Dense(91, activation='relu'),
    layers.Dense(80, activation='relu'),
    layers.Dense(60, activation='relu'),
    layers.Dense(50, activation='relu'),
    layers.Dense(30, activation='relu'),
    layers.Dense(10, activation='relu'),
    layers.Dense(2),
])
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.MeanSquaredError(),
    metrics=['accuracy']
)

# %%
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 53/53 [==============================] - 1s 4ms/step - loss: 6326.9111 - accuracy: 0.5280 - val_loss: 125.6738 - val_accuracy: 0.6667
# Epoch 2/50
# 53/53 [==============================] - 0s 2ms/step - loss: 83.3689 - accuracy: 0.6464 - val_loss: 46.5528 - val_accuracy: 0.5792
# Epoch 3/50
# 53/53 [==============================] - 0s 2ms/step - loss: 40.7942 - accuracy: 0.6387 - val_loss: 27.4886 - val_accuracy: 0.6583
# Epoch 4/50
# 53/53 [==============================] - 0s 2ms/step - loss: 27.0277 - accuracy: 0.6405 - val_loss: 22.2852 - val_accuracy: 0.6236
# Epoch 5/50
# 53/53 [==============================] - 0s 2ms/step - loss: 21.5017 - accuracy: 0.6345 - val_loss: 18.2119 - val_accuracy: 0.6167
# Epoch 6/50
# 53/53 [==============================] - 0s 2ms/step - loss: 18.5828 - accuracy: 0.6435 - val_loss: 16.3827 - val_accuracy: 0.6028
# Epoch 7/50
# 53/53 [==============================] - 0s 2ms/step - loss: 15.0815 - accuracy: 0.6446 - val_loss: 14.2466 - val_accuracy: 0.7389
# Epoch 8/50
# 53/53 [==============================] - 0s 2ms/step - loss: 12.3455 - accuracy: 0.6756 - val_loss: 12.8917 - val_accuracy: 0.7569
# Epoch 9/50
# 53/53 [==============================] - 0s 2ms/step - loss: 11.9810 - accuracy: 0.6696 - val_loss: 9.8763 - val_accuracy: 0.7444
# Epoch 10/50
# 53/53 [==============================] - 0s 2ms/step - loss: 9.6776 - accuracy: 0.6935 - val_loss: 8.7860 - val_accuracy: 0.6819
# Epoch 11/50
# 53/53 [==============================] - 0s 2ms/step - loss: 9.9296 - accuracy: 0.7226 - val_loss: 8.3668 - val_accuracy: 0.6917
# Epoch 12/50
# 53/53 [==============================] - 0s 2ms/step - loss: 8.1264 - accuracy: 0.7083 - val_loss: 8.8250 - val_accuracy: 0.7361
# Epoch 13/50
# 53/53 [==============================] - 0s 2ms/step - loss: 7.5989 - accuracy: 0.7137 - val_loss: 7.7576 - val_accuracy: 0.7625
# Epoch 14/50
# 53/53 [==============================] - 0s 2ms/step - loss: 6.5177 - accuracy: 0.7155 - val_loss: 6.8577 - val_accuracy: 0.7500
# Epoch 15/50
# 53/53 [==============================] - 0s 2ms/step - loss: 6.5109 - accuracy: 0.7226 - val_loss: 8.1654 - val_accuracy: 0.7972
# Epoch 16/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.9381 - accuracy: 0.7310 - val_loss: 6.0211 - val_accuracy: 0.6944
# Epoch 17/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.3791 - accuracy: 0.7280 - val_loss: 6.9102 - val_accuracy: 0.6764
# Epoch 18/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.7927 - accuracy: 0.7256 - val_loss: 5.0320 - val_accuracy: 0.7306
# Epoch 19/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.0893 - accuracy: 0.7464 - val_loss: 4.8151 - val_accuracy: 0.7611
# Epoch 20/50
# 53/53 [==============================] - 0s 2ms/step - loss: 4.3781 - accuracy: 0.7589 - val_loss: 4.7624 - val_accuracy: 0.6792
# Epoch 21/50
# 53/53 [==============================] - 0s 2ms/step - loss: 4.4242 - accuracy: 0.7524 - val_loss: 4.8742 - val_accuracy: 0.7250
# Epoch 22/50
# 53/53 [==============================] - 0s 2ms/step - loss: 7.0982 - accuracy: 0.7268 - val_loss: 5.2345 - val_accuracy: 0.8153
# Epoch 23/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.1394 - accuracy: 0.7381 - val_loss: 4.0671 - val_accuracy: 0.8069
# Epoch 24/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.6982 - accuracy: 0.7762 - val_loss: 3.7472 - val_accuracy: 0.7875
# Epoch 25/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.5017 - accuracy: 0.7750 - val_loss: 3.4464 - val_accuracy: 0.7875
# Epoch 26/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.4011 - accuracy: 0.7774 - val_loss: 3.6841 - val_accuracy: 0.7250
# Epoch 27/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.8974 - accuracy: 0.7661 - val_loss: 3.5383 - val_accuracy: 0.7750
# Epoch 28/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.0182 - accuracy: 0.7690 - val_loss: 3.0568 - val_accuracy: 0.8097
# Epoch 29/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.9693 - accuracy: 0.7911 - val_loss: 3.3500 - val_accuracy: 0.8361
# Epoch 30/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.0805 - accuracy: 0.7744 - val_loss: 3.7239 - val_accuracy: 0.8292
# Epoch 31/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.2116 - accuracy: 0.7935 - val_loss: 3.4559 - val_accuracy: 0.8542
# Epoch 32/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.4486 - accuracy: 0.7804 - val_loss: 3.4077 - val_accuracy: 0.7972
# Epoch 33/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.3378 - accuracy: 0.7911 - val_loss: 3.0219 - val_accuracy: 0.8736
# Epoch 34/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.9657 - accuracy: 0.7786 - val_loss: 4.6958 - val_accuracy: 0.8625
# Epoch 35/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.9377 - accuracy: 0.7738 - val_loss: 6.3513 - val_accuracy: 0.8764
# Epoch 36/50
# 53/53 [==============================] - 0s 2ms/step - loss: 4.4910 - accuracy: 0.7673 - val_loss: 3.0109 - val_accuracy: 0.7625
# Epoch 37/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.9661 - accuracy: 0.7917 - val_loss: 2.9352 - val_accuracy: 0.7958
# Epoch 38/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.6675 - accuracy: 0.7994 - val_loss: 3.6895 - val_accuracy: 0.8889
# Epoch 39/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.3934 - accuracy: 0.8107 - val_loss: 2.5626 - val_accuracy: 0.8764
# Epoch 40/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.0974 - accuracy: 0.8161 - val_loss: 3.9391 - val_accuracy: 0.8028
# Epoch 41/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.2930 - accuracy: 0.8113 - val_loss: 2.4428 - val_accuracy: 0.8819
# Epoch 42/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.0872 - accuracy: 0.8232 - val_loss: 2.3538 - val_accuracy: 0.8736
# Epoch 43/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.2187 - accuracy: 0.8232 - val_loss: 2.6684 - val_accuracy: 0.7931
# Epoch 44/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.1093 - accuracy: 0.8286 - val_loss: 2.1737 - val_accuracy: 0.8125
# Epoch 45/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.8787 - accuracy: 0.8298 - val_loss: 2.0068 - val_accuracy: 0.7556
# Epoch 46/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.9843 - accuracy: 0.8202 - val_loss: 2.1896 - val_accuracy: 0.8486
# Epoch 47/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.1399 - accuracy: 0.8214 - val_loss: 2.9926 - val_accuracy: 0.7153
# Epoch 48/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.0262 - accuracy: 0.8393 - val_loss: 2.1229 - val_accuracy: 0.8167
# Epoch 49/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.8327 - accuracy: 0.8399 - val_loss: 1.8338 - val_accuracy: 0.8986
# Epoch 50/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.5956 - accuracy: 0.8464 - val_loss: 2.3317 - val_accuracy: 0.7667

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.ylim([0, 20])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %% [markdown]
# ## Create submission

# %%
test_output = model(preprocess(test_all_data, train=False).to_numpy())

# %%
test_output
# Out:
# <tf.Tensor: shape=(600, 2), dtype=float32, numpy=
# array([[ 0.1543167 ,  1.8530254 ],
#        [-0.18921205,  3.475775  ],
#        [ 0.29773214,  3.4312265 ],
#        ...,
#        [ 0.2696903 ,  0.7878944 ],
#        [ 0.32003763,  2.3561819 ],
#        [ 0.1747692 ,  2.0952587 ]], dtype=float32)>

# %%
pd.DataFrame({
    'id':list(range(1, test_output.shape[0]+1)),
    'formation_energy_ev_natom': test_output[:, 0],
    'bandgap_energy_ev': test_output[:, 1]
}).to_csv('submissions/neural_network_op.csv', index=False)
