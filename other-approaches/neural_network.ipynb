# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import numpy.linalg as LA
from copy import deepcopy
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# 2022-04-17 17:58:27.130410: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-17 17:58:27.130432: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
DATA_PATH = '../nomad2018-predict-transparent-conductors'

def custom_converter(entry):
    return np.array([float(x) for x in entry[1:-1].split(',')])

train_all_data = pd.read_csv(
    f'{DATA_PATH}/train_extrainfo.csv',
    converters={
        'CoulombMatrix':custom_converter,
        'SineMatrix':custom_converter,
        'EwaldSumMatrix':custom_converter
    }
)
test_all_data = pd.read_csv(
    f'{DATA_PATH}/test_extrainfo.csv',
    converters={
        'CoulombMatrix':custom_converter,
        'SineMatrix':custom_converter,
        'EwaldSumMatrix':custom_converter
    }
)

# %%
train_all_data.columns
# Out:
# Index(['id', 'spacegroup', 'number_of_total_atoms', 'percent_atom_al',
#        'percent_atom_ga', 'percent_atom_in', 'lattice_vector_1_ang',
#        'lattice_vector_2_ang', 'lattice_vector_3_ang',
#        'lattice_angle_alpha_degree', 'lattice_angle_beta_degree',
#        'lattice_angle_gamma_degree', 'formation_energy_ev_natom',
#        'bandgap_energy_ev', 'CoulombMatrix', 'SineMatrix', 'EwaldSumMatrix'],
#       dtype='object')

# %%
def get_eigenspectrum(matrix):
    spectrum = LA.eigvalsh(matrix)
    spectrum = np.sort(spectrum)[::-1]
    return spectrum

def preprocess(data, train=True):
    data = deepcopy(data)
    spectrum_list = []
    for m in data['SineMatrix']:
        spectrum_list.append(
            get_eigenspectrum(
                np.reshape(m, (80, 80))
            )
        )
    spectrum_df = pd.DataFrame(spectrum_list).astype(float)
    if train:
        to_drop = ['id', 'formation_energy_ev_natom', 'bandgap_energy_ev',
                'CoulombMatrix', 'SineMatrix', 'EwaldSumMatrix']
    else:
        to_drop = ['id',
               'CoulombMatrix', 'SineMatrix', 'EwaldSumMatrix']
    dfcombined = pd.concat([data, spectrum_df], axis=1).drop(to_drop, axis=1)
    return dfcombined

# %%
target_cols = ['formation_energy_ev_natom','bandgap_energy_ev']
data = preprocess(train_all_data)

X_train, X_test, y_train, y_test = train_test_split(data, train_all_data[target_cols], test_size = 0.30, random_state=1)

# %%
X_train
# Out:
#       spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 60           206                   80.0           0.0938           0.6875
# 2079         206                   80.0           0.4062           0.2500
# 1395          33                   40.0           0.0000           0.6250
# 2227          33                   80.0           0.0000           0.3125
# 701          206                   80.0           0.7500           0.2500
# ...          ...                    ...              ...              ...
# 960          167                   30.0           0.0000           0.1667
# 905           33                   80.0           0.3438           0.0312
# 1096          12                   80.0           0.5000           0.1875
# 235          167                   30.0           0.4167           0.0833
# 1061          12                   80.0           0.0312           0.3125
#
#       percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 60             0.2188                9.5583                9.5583
# 2079           0.3438                9.5382                9.5379
# 1395           0.3750                5.3302                9.1151
# 2227           0.6875               11.0070                9.3773
# 701            0.0000                9.0894                9.0888
# ...               ...                   ...                   ...
# 960            0.8333                5.4918                5.4913
# 905            0.6250               10.7770                9.1878
# 1096           0.3125               24.3195                6.2018
# 235            0.5000                5.2158                5.2154
# 1061           0.6562               24.7160                6.5275
#
#       lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 60                  9.5580                     90.0045
# 2079                9.5380                     90.0024
# 1395                9.7342                     89.9979
# 2227                9.9993                     89.9990
# 701                 9.0890                     90.0034
# ...                    ...                         ...
# 960                14.5600                     89.9984
# 905                 9.8151                     90.0022
# 1096                6.0952                     89.9996
# 235                13.9784                     89.9940
# 1061                6.5440                     90.0003
#
#       lattice_angle_beta_degree  ...         70         71         72  \
# 60                      90.0040  ...  51.278905  51.192050  50.684798
# 2079                    90.0027  ...  48.124473  47.073484  46.151431
# 1395                    89.9997  ...   0.000000   0.000000   0.000000
# 2227                    89.9976  ...  53.141250  52.234727  52.214577
# 701                     90.0041  ...  38.356714  37.568985  36.881481
# ...                         ...  ...        ...        ...        ...
# 960                     89.9993  ...   0.000000   0.000000   0.000000
# 905                     89.9990  ...  51.358700  50.391844  49.539896
# 1096                   104.7008  ...  40.919317  40.599176  38.824526
# 235                     90.0058  ...   0.000000   0.000000   0.000000
# 1061                   105.4012  ...  48.229816  46.007868  43.207590
#
#              73         74         75         76         77         78  \
# 60    50.255256  49.243095  48.444891  48.437744  47.624117  41.435008
# 2079  44.098866  41.950107  40.599060  39.816876  38.936680  37.261905
# 1395   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 2227  51.469821  51.383424  50.551757  47.950949  47.940750  47.005041
# 701   35.529089  34.133708  33.929112  31.491647  31.410154  30.403501
# ...         ...        ...        ...        ...        ...        ...
# 960    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 905   49.029609  48.132958  47.697284  46.699077  46.315230  46.134322
# 1096  36.662027  35.667331  32.352772  29.573998  25.913214  24.889890
# 235    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1061  43.093109  41.523991  34.572891  33.415265  30.085081  29.948745
#
#              79
# 60    39.785544
# 2079  34.584100
# 1395   0.000000
# 2227  45.728682
# 701   23.782710
# ...         ...
# 960    0.000000
# 905   42.784553
# 1096  23.723443
# 235    0.000000
# 1061  28.716507
#
# [1680 rows x 91 columns]

# %%
X_train.to_numpy().shape
# Out:
# (1680, 91)

# %%
model = models.Sequential([
    layers.Dense(91, activation='relu'),
    layers.Dense(80, activation='relu'),
    layers.Dense(60, activation='relu'),
    layers.Dense(50, activation='relu'),
    layers.Dense(30, activation='relu'),
    layers.Dense(10, activation='relu'),
    layers.Dense(2),
])
model.compile(
    optimizer='adam',
    loss = tf.keras.losses.MeanSquaredError(),
    metrics=['accuracy']
)

# %%
history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 53/53 [==============================] - 1s 4ms/step - loss: 584.5800 - accuracy: 0.5381 - val_loss: 66.0626 - val_accuracy: 0.3000
# Epoch 2/50
# 53/53 [==============================] - 0s 2ms/step - loss: 40.5082 - accuracy: 0.5952 - val_loss: 28.7827 - val_accuracy: 0.8361
# Epoch 3/50
# 53/53 [==============================] - 0s 2ms/step - loss: 18.8065 - accuracy: 0.6262 - val_loss: 15.2619 - val_accuracy: 0.4528
# Epoch 4/50
# 53/53 [==============================] - 0s 1ms/step - loss: 12.8672 - accuracy: 0.6417 - val_loss: 10.6098 - val_accuracy: 0.4500
# Epoch 5/50
# 53/53 [==============================] - 0s 2ms/step - loss: 10.1257 - accuracy: 0.6446 - val_loss: 7.8865 - val_accuracy: 0.7375
# Epoch 6/50
# 53/53 [==============================] - 0s 2ms/step - loss: 9.8579 - accuracy: 0.6524 - val_loss: 6.0136 - val_accuracy: 0.6222
# Epoch 7/50
# 53/53 [==============================] - 0s 2ms/step - loss: 6.1954 - accuracy: 0.7012 - val_loss: 5.3380 - val_accuracy: 0.7417
# Epoch 8/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.7204 - accuracy: 0.6952 - val_loss: 5.2526 - val_accuracy: 0.8750
# Epoch 9/50
# 53/53 [==============================] - 0s 2ms/step - loss: 6.0094 - accuracy: 0.6929 - val_loss: 6.7315 - val_accuracy: 0.3653
# Epoch 10/50
# 53/53 [==============================] - 0s 2ms/step - loss: 4.1765 - accuracy: 0.7357 - val_loss: 3.8987 - val_accuracy: 0.7764
# Epoch 11/50
# 53/53 [==============================] - 0s 2ms/step - loss: 4.1535 - accuracy: 0.7381 - val_loss: 4.2320 - val_accuracy: 0.8958
# Epoch 12/50
# 53/53 [==============================] - 0s 3ms/step - loss: 3.5718 - accuracy: 0.7435 - val_loss: 3.6779 - val_accuracy: 0.8847
# Epoch 13/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.4926 - accuracy: 0.7417 - val_loss: 3.5485 - val_accuracy: 0.8389
# Epoch 14/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.0800 - accuracy: 0.7643 - val_loss: 3.0581 - val_accuracy: 0.6556
# Epoch 15/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.3977 - accuracy: 0.7411 - val_loss: 2.6995 - val_accuracy: 0.8431
# Epoch 16/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.2827 - accuracy: 0.7435 - val_loss: 2.5782 - val_accuracy: 0.8194
# Epoch 17/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.9375 - accuracy: 0.7643 - val_loss: 4.1888 - val_accuracy: 0.4819
# Epoch 18/50
# 53/53 [==============================] - 0s 2ms/step - loss: 4.5362 - accuracy: 0.7167 - val_loss: 5.9239 - val_accuracy: 0.9722
# Epoch 19/50
# 53/53 [==============================] - 0s 2ms/step - loss: 4.4396 - accuracy: 0.7268 - val_loss: 2.3016 - val_accuracy: 0.8139
# Epoch 20/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.1753 - accuracy: 0.8060 - val_loss: 2.1661 - val_accuracy: 0.8569
# Epoch 21/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.1301 - accuracy: 0.7988 - val_loss: 2.3057 - val_accuracy: 0.9069
# Epoch 22/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.1329 - accuracy: 0.7970 - val_loss: 2.2417 - val_accuracy: 0.8917
# Epoch 23/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.3081 - accuracy: 0.7970 - val_loss: 2.1019 - val_accuracy: 0.6931
# Epoch 24/50
# 53/53 [==============================] - 0s 2ms/step - loss: 3.5373 - accuracy: 0.7440 - val_loss: 4.5947 - val_accuracy: 0.2986
# Epoch 25/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.0481 - accuracy: 0.8000 - val_loss: 4.4898 - val_accuracy: 0.3333
# Epoch 26/50
# 53/53 [==============================] - 0s 2ms/step - loss: 5.9409 - accuracy: 0.6810 - val_loss: 2.3520 - val_accuracy: 0.6708
# Epoch 27/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.5956 - accuracy: 0.7696 - val_loss: 3.7242 - val_accuracy: 0.5028
# Epoch 28/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.8439 - accuracy: 0.8036 - val_loss: 1.7393 - val_accuracy: 0.9472
# Epoch 29/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.7322 - accuracy: 0.8060 - val_loss: 1.7929 - val_accuracy: 0.7222
# Epoch 30/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.4918 - accuracy: 0.8423 - val_loss: 1.4424 - val_accuracy: 0.7514
# Epoch 31/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.3609 - accuracy: 0.7833 - val_loss: 2.1687 - val_accuracy: 0.9278
# Epoch 32/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.6101 - accuracy: 0.8220 - val_loss: 1.3913 - val_accuracy: 0.8736
# Epoch 33/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.2167 - accuracy: 0.8589 - val_loss: 1.3773 - val_accuracy: 0.9500
# Epoch 34/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.1909 - accuracy: 0.8631 - val_loss: 1.9858 - val_accuracy: 0.6167
# Epoch 35/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.4495 - accuracy: 0.8292 - val_loss: 1.2433 - val_accuracy: 0.7931
# Epoch 36/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.2964 - accuracy: 0.8381 - val_loss: 1.2152 - val_accuracy: 0.8819
# Epoch 37/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.3841 - accuracy: 0.8327 - val_loss: 2.7093 - val_accuracy: 0.5000
# Epoch 38/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.4103 - accuracy: 0.7470 - val_loss: 1.9224 - val_accuracy: 0.9708
# Epoch 39/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.3752 - accuracy: 0.8357 - val_loss: 1.6628 - val_accuracy: 0.6347
# Epoch 40/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9869 - accuracy: 0.8756 - val_loss: 1.0875 - val_accuracy: 0.9306
# Epoch 41/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.1016 - accuracy: 0.8607 - val_loss: 0.9388 - val_accuracy: 0.8819
# Epoch 42/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.9639 - accuracy: 0.8643 - val_loss: 1.3199 - val_accuracy: 0.9667
# Epoch 43/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0341 - accuracy: 0.8661 - val_loss: 1.4056 - val_accuracy: 0.6500
# Epoch 44/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.4929 - accuracy: 0.8327 - val_loss: 1.0614 - val_accuracy: 0.9306
# Epoch 45/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.0277 - accuracy: 0.8595 - val_loss: 0.9340 - val_accuracy: 0.8333
# Epoch 46/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.7762 - accuracy: 0.9018 - val_loss: 0.8859 - val_accuracy: 0.9292
# Epoch 47/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8130 - accuracy: 0.8940 - val_loss: 0.8769 - val_accuracy: 0.8139
# Epoch 48/50
# 53/53 [==============================] - 0s 2ms/step - loss: 0.8933 - accuracy: 0.8768 - val_loss: 1.8392 - val_accuracy: 0.9819
# Epoch 49/50
# 53/53 [==============================] - 0s 2ms/step - loss: 1.7643 - accuracy: 0.7804 - val_loss: 6.2540 - val_accuracy: 0.9847
# Epoch 50/50
# 53/53 [==============================] - 0s 2ms/step - loss: 2.3894 - accuracy: 0.7446 - val_loss: 1.0025 - val_accuracy: 0.9306

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.ylim([0, 80])
plt.legend(loc='upper right')

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
# plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %% [markdown]
# ## Create submission

# %%
test_output = model(preprocess(test_all_data, train=False).to_numpy())

# %%
test_output
# Out:
# <tf.Tensor: shape=(600, 2), dtype=float32, numpy=
# array([[ 0.1543167 ,  1.8530254 ],
#        [-0.18921205,  3.475775  ],
#        [ 0.29773214,  3.4312265 ],
#        ...,
#        [ 0.2696903 ,  0.7878944 ],
#        [ 0.32003763,  2.3561819 ],
#        [ 0.1747692 ,  2.0952587 ]], dtype=float32)>

# %%
pd.DataFrame({
    'id':list(range(1, test_output.shape[0]+1)),
    'formation_energy_ev_natom': test_output[:, 0],
    'bandgap_energy_ev': test_output[:, 1]
}).to_csv('submissions/neural_network_op.csv', index=False)
